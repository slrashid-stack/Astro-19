# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,100)

# %%
def exp(x):
    return np.exp(x)

# %%
y = np.exp(x)

# %%
plt.plot(x,y)
plt.xlabel("Time[miliseconds]")
plt.ylabel("Awesomeness")
# Out:
# Text(0, 0.5, 'Awesomeness')

# %%
plt.savefig("demo",format='pdf')
