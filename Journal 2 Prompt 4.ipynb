# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.power(1,1000)

# %%
plt.hist(x, bins=100, alpha=0.9, edgecolor="purple")
plt.xlabel("x")
plt.ylabel("number per bin")
# Out:
# Text(0, 0.5, 'number per bin')

# %%
plt.savefig("demo.pdf", format="pdf")
